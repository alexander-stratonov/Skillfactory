# %%
import pandas as pd
from IPython.display import display
data = pd.read_excel('C:/Users/user/Documents/GitHub/Skillfactory_Alexander_Stratonov/module_3/data/Fig3-1.xls', header=None)  
data
# Out:
#                                                     0           1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...         NaN  NaN
# 1                See the book for description of data.         NaN  NaN
# 2    Monthly data from January 1953 for prices, all...         NaN  NaN
# 3                                                  NaN        Real  NaN
# 4                                                  NaN        Home  NaN
# ..                                                 ...         ...  ...
# 859                                        2018.791667  174.056034  NaN
# 860                                           2018.875  174.438912  NaN
# 861                                        2018.958333  174.658876  NaN
# 862                                        2019.041667   174.01623  NaN
# 863                                                NaN         NaN  NaN
#
#            3                                                  4    5    6   \
# ...

# %%
data_file = pd.ExcelFile('C:/Users/user/Documents/GitHub/Skillfactory_Alexander_Stratonov/module_3/data/Fig3-1.xls')  
data = pd.read_excel(data_file, header=None)
data
# Out:
#                                                     0           1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...         NaN  NaN
# 1                See the book for description of data.         NaN  NaN
# 2    Monthly data from January 1953 for prices, all...         NaN  NaN
# 3                                                  NaN        Real  NaN
# 4                                                  NaN        Home  NaN
# ..                                                 ...         ...  ...
# 859                                        2018.791667  174.056034  NaN
# 860                                           2018.875  174.438912  NaN
# 861                                        2018.958333  174.658876  NaN
# 862                                        2019.041667   174.01623  NaN
# 863                                                NaN         NaN  NaN
#
#            3                                                  4    5    6   \
# ...

# %%
data = pd.read_excel('C:/Users/user/Documents/GitHub/Skillfactory_Alexander_Stratonov/module_3/data/Fig3-1.xls', ['Sheet1', 'Sheet2'])  
data
# Out:
# {'Sheet1':       Unnamed: 0 Unnamed: 1
#  0            NaN        NaN
#  1            NaN        NaN
#  2            NaN   Consumer
#  3            NaN      Price
#  4            NaN      Index
#  ..           ...        ...
#  858  2018.791667    252.885
#  859     2018.875    252.038
#  860  2018.958333    251.233
#  861  2019.041667    251.712
#  862     2019.125    252.776
#
#  [863 rows x 2 columns],
#  'Sheet2':         CPI Annual&
#  0         Quarterly
#  1    Warren&Pearson
#  2    Warren&Pearson
#  3    Warren&Pearson
#  4    Warren&Pearson
#  ..              ...
#  853             BLS
#  854             BLS
#  855             BLS
#  856             BLS
#  857             BLS
#
#  [858 rows x 1 columns]}

# %%
data = pd.read_excel('http://www.econ.yale.edu/~shiller/data/Fig3-1.xls', header=None)  
data
# Out:
#                                                     0           1    2   \
# 0    U.S. Home Price and Related data, for Figure 3...         NaN  NaN
# 1                See the book for description of data.         NaN  NaN
# 2    Monthly data from January 1953 for prices, all...         NaN  NaN
# 3                                                  NaN        Real  NaN
# 4                                                  NaN        Home  NaN
# ..                                                 ...         ...  ...
# 891                                        2021.458333  213.586849  NaN
# 892                                        2021.541667  215.873377  NaN
# 893                                                NaN     1.71408  NaN
# 894                                                NaN         NaN  NaN
# 895                                                NaN    1.177299  NaN
#
#            3                                                  4    5    6   \
# ...

# %%
data = pd.read_excel("C:/Users/user/Documents/GitHub/Skillfactory_Alexander_Stratonov/module_3/data/nakladnaya.xls"
                     , header=None, skiprows=2)
data
# Out:
#     0                                  1   \
# 0  NaN                                NaN
# 1  NaN                                NaN
# 2  NaN                  Грузоотправитель:
# 3  NaN                                NaN
# 4  NaN                   Грузополучатель:
# 5  NaN                                NaN
# 6  NaN  Основание для отпуска: Договор №
# 7  NaN                                NaN
# 8  NaN                                NaN
# 9  NaN                                  №
# 10 NaN                                п/п
# 11 NaN                                  1
# 12 NaN                                  2
# 13 NaN                                NaN
# 14 NaN                                NaN
# 15 NaN                                NaN
# 16 NaN                                NaN
# 17 NaN                                NaN
# 18 NaN                                NaN
# 19 NaN                                NaN
# 20 NaN                                NaN
# ...

# %%
data=data.dropna(how='all')
len(data)
# Out:
# 15

# %%
data.iloc[0, 4][2:9]
# Out:
# '5764809'

# %%
display(data.iloc[6:8, [1, 2, 6, 9, 11, 12]])
display(data.iloc[6:8, :].dropna(axis=1, how='any'))
display(data.iloc[6:8, :].dropna(axis=1, how='all'))
# Out:
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000
#    1                      2   6   9     11     12
# 11  1  Велосипед "Спринтер"   шт   5  9000  45000
# 12  2    Велосипед "Малютка"  шт  10  3500  35000

# %% [raw]
# %pip install xlsxwriter
#
# table.to_csv("table.csv")
#
# table.to_excel("table.xls")
#
# writer = pd.ExcelWriter('test.xlsx')
# table.to_excel(writer, index=False, sheet_name='Таблица')
# writer.save()
#
# workbook = writer.book
# worksheet = writer.sheets['Таблица']
#
# money_fmt = workbook.add_format({'bold': True})
# name_fmt = workbook.add_format({'color': 'red'})
#
# worksheet.set_column('E:F', 20, money_fmt)
# worksheet.set_column(1, 1, 20, name_fmt)
#
# writer = pd.ExcelWriter('test.xlsx', engine='xlsxwriter')
